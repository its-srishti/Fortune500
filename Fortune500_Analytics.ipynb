# %%
#importing relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_df = pd.read_csv(r"/content/preprocessed_fortune500_data.csv")

# %%
df = raw_df.copy()

# %%
df.head()
# Out:
#    Year  Rank                Name  Average CPI   Revenue  Adjusted Revenue
# 0  2021     1             Walmart        271.0  559151.0          559151.0
# 1  2021     2              Amazon        271.0  386064.0          386064.0
# 2  2021     3               Apple        271.0  274515.0          274515.0
# 3  2021     4                 CVS        271.0  268706.0          268706.0
# 4  2021     5  UnitedHealth Group        271.0  257141.0          257141.0

# %%
# Split the data into training and test sets
train_df = df[df['Year'] <= 2015]
test_df = df[df['Year'] > 2015]

# %%
# Get the last adjusted revenue of each year for the training data
train_last_adjusted_revenue = train_df.groupby('Year')['Adjusted Revenue'].min()

# %%
# Get the last adjusted revenue of each year for the test data
test_last_adjusted_revenue = test_df.groupby('Year')['Adjusted Revenue'].min()

# %%
# Plot the relationship between Year and Adjusted Revenue
plt.figure(figsize=(10, 6))

# Convert the Series to DataFrame and reset the index
plot_df = train_last_adjusted_revenue.to_frame().reset_index()

sns.lineplot(x='Year', y='Adjusted Revenue', data=plot_df, color='b', label='Min Adjusted Revenue')

# Adding titles and labels for clarity
plt.title('Year vs. Minimum Adjusted Revenue in Training Data', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Min Adjusted Revenue (Adjusted to 2021)', fontsize=12)

# Display the graph
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Scale the data
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_last_adjusted_revenue.values.reshape(-1, 1))
test_scaled = scaler.transform(test_last_adjusted_revenue.values.reshape(-1, 1))

# %%
# Reshape the data for LSTM
train_X = train_scaled[:-1]
train_y = train_scaled[1:]
test_X = test_scaled[:-1]
test_y = test_scaled[1:]

# %%
# Create the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_X.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(train_X, train_y, epochs=100, batch_size=32, verbose=2)
# Make predictions on the test data
test_pred = model.predict(test_X)
# Out:
# Epoch 1/100
# 2/2 - 3s - 2s/step - loss: 0.2545
# Epoch 2/100
# 2/2 - 0s - 21ms/step - loss: 0.2473
# Epoch 3/100
# 2/2 - 0s - 30ms/step - loss: 0.2397
# Epoch 4/100
# 2/2 - 0s - 29ms/step - loss: 0.2331
# Epoch 5/100
# 2/2 - 0s - 22ms/step - loss: 0.2259
# Epoch 6/100
# 2/2 - 0s - 31ms/step - loss: 0.2188
# Epoch 7/100
# 2/2 - 0s - 25ms/step - loss: 0.2118
# Epoch 8/100
# 2/2 - 0s - 36ms/step - loss: 0.2043
# Epoch 9/100
# 2/2 - 0s - 68ms/step - loss: 0.1966
# Epoch 10/100
# 2/2 - 0s - 80ms/step - loss: 0.1895
# Epoch 11/100
# 2/2 - 0s - 152ms/step - loss: 0.1823
# Epoch 12/100
# 2/2 - 0s - 52ms/step - loss: 0.1738
# Epoch 13/100
# 2/2 - 0s - 52ms/step - loss: 0.1668
# Epoch 14/100
# 2/2 - 0s - 79ms/step - loss: 0.1580
# Epoch 15/100
# 2/2 - 0s - 64ms/step - loss: 0.1505
# Epoch 16/100
# 2/2 - 0s - 52ms/step - loss: 0.1412
# Epoch 17/100
# 2/2 - 0s - 78ms/step - loss: 0.1339
# Epoch 18/100
# 2/2 - 0s - 41ms/step - loss: 0.1253
# Epoch 19/100
# 2/2 - 0s - 29ms/step - loss: 0.1172
# Epoch 20/100
# 2/2 - 0s - 25ms/step - loss: 0.1081
# Epoch 21/100
# 2/2 - 0s - 28ms/step - loss: 0.1007
# Epoch 22/100
# 2/2 - 0s - 36ms/step - loss: 0.0939
# Epoch 23/100
# 2/2 - 0s - 23ms/step - loss: 0.0863
# Epoch 24/100
# 2/2 - 0s - 30ms/step - loss: 0.0804
# Epoch 25/100
# 2/2 - 0s - 30ms/step - loss: 0.0751
# Epoch 26/100
# 2/2 - 0s - 24ms/step - loss: 0.0702
# Epoch 27/100
# 2/2 - 0s - 16ms/step - loss: 0.0655
# Epoch 28/100
# 2/2 - 0s - 15ms/step - loss: 0.0625
# Epoch 29/100
# 2/2 - 0s - 16ms/step - loss: 0.0603
# Epoch 30/100
# 2/2 - 0s - 20ms/step - loss: 0.0582
# Epoch 31/100
# 2/2 - 0s - 18ms/step - loss: 0.0565
# Epoch 32/100
# 2/2 - 0s - 25ms/step - loss: 0.0548
# Epoch 33/100
# 2/2 - 0s - 18ms/step - loss: 0.0531
# Epoch 34/100
# 2/2 - 0s - 16ms/step - loss: 0.0513
# Epoch 35/100
# 2/2 - 0s - 16ms/step - loss: 0.0491
# Epoch 36/100
# 2/2 - 0s - 15ms/step - loss: 0.0468
# Epoch 37/100
# 2/2 - 0s - 29ms/step - loss: 0.0444
# Epoch 38/100
# 2/2 - 0s - 14ms/step - loss: 0.0418
# Epoch 39/100
# 2/2 - 0s - 30ms/step - loss: 0.0395
# Epoch 40/100
# 2/2 - 0s - 16ms/step - loss: 0.0370
# Epoch 41/100
# 2/2 - 0s - 16ms/step - loss: 0.0347
# Epoch 42/100
# 2/2 - 0s - 16ms/step - loss: 0.0324
# Epoch 43/100
# 2/2 - 0s - 15ms/step - loss: 0.0302
# Epoch 44/100
# 2/2 - 0s - 15ms/step - loss: 0.0283
# Epoch 45/100
# 2/2 - 0s - 16ms/step - loss: 0.0263
# Epoch 46/100
# 2/2 - 0s - 15ms/step - loss: 0.0244
# Epoch 47/100
# 2/2 - 0s - 18ms/step - loss: 0.0224
# Epoch 48/100
# 2/2 - 0s - 15ms/step - loss: 0.0207
# Epoch 49/100
# 2/2 - 0s - 16ms/step - loss: 0.0191
# Epoch 50/100
# 2/2 - 0s - 16ms/step - loss: 0.0174
# Epoch 51/100
# 2/2 - 0s - 15ms/step - loss: 0.0159
# Epoch 52/100
# 2/2 - 0s - 30ms/step - loss: 0.0145
# Epoch 53/100
# 2/2 - 0s - 30ms/step - loss: 0.0132
# Epoch 54/100
# 2/2 - 0s - 30ms/step - loss: 0.0121
# Epoch 55/100
# 2/2 - 0s - 19ms/step - loss: 0.0111
# Epoch 56/100
# 2/2 - 0s - 24ms/step - loss: 0.0102
# Epoch 57/100
# 2/2 - 0s - 20ms/step - loss: 0.0093
# Epoch 58/100
# 2/2 - 0s - 18ms/step - loss: 0.0087
# Epoch 59/100
# 2/2 - 0s - 18ms/step - loss: 0.0081
# Epoch 60/100
# 2/2 - 0s - 29ms/step - loss: 0.0076
# Epoch 61/100
# 2/2 - 0s - 14ms/step - loss: 0.0072
# Epoch 62/100
# 2/2 - 0s - 15ms/step - loss: 0.0069
# Epoch 63/100
# 2/2 - 0s - 15ms/step - loss: 0.0065
# Epoch 64/100
# 2/2 - 0s - 16ms/step - loss: 0.0064
# Epoch 65/100
# 2/2 - 0s - 15ms/step - loss: 0.0062
# Epoch 66/100
# 2/2 - 0s - 16ms/step - loss: 0.0061
# Epoch 67/100
# 2/2 - 0s - 16ms/step - loss: 0.0060
# Epoch 68/100
# 2/2 - 0s - 18ms/step - loss: 0.0060
# Epoch 69/100
# 2/2 - 0s - 28ms/step - loss: 0.0059
# Epoch 70/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 71/100
# 2/2 - 0s - 14ms/step - loss: 0.0059
# Epoch 72/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 73/100
# 2/2 - 0s - 30ms/step - loss: 0.0059
# Epoch 74/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 75/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 76/100
# 2/2 - 0s - 29ms/step - loss: 0.0059
# Epoch 77/100
# 2/2 - 0s - 18ms/step - loss: 0.0059
# Epoch 78/100
# 2/2 - 0s - 32ms/step - loss: 0.0059
# Epoch 79/100
# 2/2 - 0s - 29ms/step - loss: 0.0059
# Epoch 80/100
# 2/2 - 0s - 67ms/step - loss: 0.0059
# Epoch 81/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 82/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 83/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 84/100
# 2/2 - 0s - 30ms/step - loss: 0.0059
# Epoch 85/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 86/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 87/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 88/100
# 2/2 - 0s - 19ms/step - loss: 0.0059
# Epoch 89/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 90/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 91/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 92/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 93/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 94/100
# 2/2 - 0s - 15ms/step - loss: 0.0059
# Epoch 95/100
# 2/2 - 0s - 30ms/step - loss: 0.0059
# Epoch 96/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 97/100
# 2/2 - 0s - 18ms/step - loss: 0.0059
# Epoch 98/100
# 2/2 - 0s - 16ms/step - loss: 0.0059
# Epoch 99/100
# 2/2 - 0s - 34ms/step - loss: 0.0059
# Epoch 100/100
# 2/2 - 0s - 19ms/step - loss: 0.0059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step

# %%
# Evaluate the model
mse = model.evaluate(test_X, test_y)
print(f'MSE: {mse:.2f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 0.0067
# MSE: 0.01

# %%
# Plot the results
plt.plot(train_last_adjusted_revenue.index, train_last_adjusted_revenue.values, label='Training Data')
plt.plot(test_last_adjusted_revenue.index, test_last_adjusted_revenue.values, label='Test Data')
plt.plot(test_last_adjusted_revenue.index[1:], scaler.inverse_transform(test_pred), label='Predicted')
plt.xlabel('Year')
plt.ylabel('Minimum Adjusted Revenue')
plt.title('Minimum Adjusted Revenue Over Time - LSTM')
plt.legend()
plt.show()

# %% [markdown]
# Since revenue is the sole dependent variable, the model is unable to capture the sharp decline observed in 2020 and instead predicts continued revenue growth. Additionally, the apparent break in the time series arises from missing data for 2015, which were removed due to their limited presence in the dataset.
